# %%
#assignment work - deployment of multi liniear regeression model

# %%
import pickle

# %%
#already we checked the saved model by loading it once - during creation, just copy,paste that code
loaded_model=pickle.load(open("finalised_model_Multilinear.sav",'rb'))
result=loaded_model.predict([[1234,345,4565,1,0]])

# %%
#just print and check the result once
result
# Out:
# array([[42727.81192773]])

# %%
# now simply check for 0 rupee investment in r&D, admin,marketing , florida state
loaded_model=pickle.load(open("finalised_model_Multilinear.sav",'rb'))
result=loaded_model.predict([[0,0,0,1,0]])
result
# Out:
# array([[41594.88345768]])

# %%
# now simply check for diff amt of rupees investment in r&D, admin,marketing , florida state
loaded_model=pickle.load(open("finalised_model_Multilinear.sav",'rb'))
result=loaded_model.predict([[2000,1000,400,1,0]])
result
# Out:
# array([[43189.34645102]])
