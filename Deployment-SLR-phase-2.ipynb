# %%
import pickle

# %%
#already we checked the saved model by loading it once - during creation, just copy,paste that code
loaded_model=pickle.load(open("finalised_model_linear.sav",'rb'))
result=loaded_model.predict([[13]])

# %%
#just print and check the result once
result
# Out:
# array([146913.31828543])

# %%
# now simply check for 0 years of experience
loaded_model=pickle.load(open("finalised_model_linear.sav",'rb'))
result=loaded_model.predict([[0]])
result
# Out:
# array([25849.84163796])

# %%
#whatever the result ---> output is --->bias value (base value) --> previously we,
#we chekced bias value during model creation time (bias/origin/intercept - all same)
