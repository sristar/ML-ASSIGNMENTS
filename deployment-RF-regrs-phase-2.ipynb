# %%
#assignment work - deployment of Random Forest Regeression model

# %%
import pickle

# %%
#already we checked the saved model by loading it once - during creation, just copy,paste that code
loaded_model=pickle.load(open("finalised_model_RF_regrs.sav",'rb'))
result=loaded_model.predict([[1234,345,4565,1,0]])

# %%
#just print and check the result once
result
# Out:
# array([49732.8126])

# %%
# now simply check for 0 rupee investment in r&D, admin,marketing , new-york state

loaded_model=pickle.load(open("finalised_model_RF_regrs.sav",'rb'))
result=loaded_model.predict([[0,0,0,0,0]])
result
# Out:
# array([33976.697])

# %%
# now simply check for diff amt of rupees investment in r&D, admin,marketing , florida state
loaded_model=pickle.load(open("finalised_model_RF_regrs.sav",'rb'))
result=loaded_model.predict([[500,600,700,1,0]])
result
# Out:
# array([35519.2254])
