# %%
#it imports and stores in memory the panda - library - which has dataset related functions
#storing it as pd
import pandas as pd

# %%
#dataset is the variable which holds the value of salary_dataset.csv
#pd is the class and read_csv is the function to read the csv file
dataset=pd.read_csv("Salary_dataset.csv")

# %%
#printing dataset variable
dataset
# Out:
#     Unnamed: 0  YearsExperience    Salary
# 0            0              1.2   39344.0
# 1            1              1.4   46206.0
# 2            2              1.6   37732.0
# 3            3              2.1   43526.0
# 4            4              2.3   39892.0
# 5            5              3.0   56643.0
# 6            6              3.1   60151.0
# 7            7              3.3   54446.0
# 8            8              3.3   64446.0
# 9            9              3.8   57190.0
# 10          10              4.0   63219.0
# 11          11              4.1   55795.0
# 12          12              4.1   56958.0
# 13          13              4.2   57082.0
# 14          14              4.6   61112.0
# 15          15              5.0   67939.0
# 16          16              5.2   66030.0
# 17          17              5.4   83089.0
# 18          18              6.0   81364.0
# 19          19              6.1   93941.0
# 20          20              6.9   91739.0
# ...

# %%
#independent variable in input values, taking input value yearsofexp in a variable called independent.
independent=dataset["YearsExperience"]

# %%
#dependent variable in output values, taking output value salary in a variable called dependent.
dependent=dataset["Salary"]

# %%
#dispalying just to know wtr it is saved proper in the variables
independent
# Out:
# 0      1.2
# 1      1.4
# 2      1.6
# 3      2.1
# 4      2.3
# 5      3.0
# 6      3.1
# 7      3.3
# 8      3.3
# 9      3.8
# 10     4.0
# 11     4.1
# 12     4.1
# 13     4.2
# 14     4.6
# 15     5.0
# 16     5.2
# 17     5.4
# 18     6.0
# 19     6.1
# 20     6.9
# 21     7.2
# 22     8.0
# 23     8.3
# 24     8.8
# 25     9.1
# 26     9.6
# 27     9.7
# 28    10.4
# 29    10.6
# Name: YearsExperience, dtype: float64

# %%
#dispalying just to know wtr it is saved proper in the variables
dependent
# Out:
# 0      39344.0
# 1      46206.0
# 2      37732.0
# 3      43526.0
# 4      39892.0
# 5      56643.0
# 6      60151.0
# 7      54446.0
# 8      64446.0
# 9      57190.0
# 10     63219.0
# 11     55795.0
# 12     56958.0
# 13     57082.0
# 14     61112.0
# 15     67939.0
# 16     66030.0
# 17     83089.0
# 18     81364.0
# 19     93941.0
# 20     91739.0
# 21     98274.0
# 22    101303.0
# 23    113813.0
# 24    109432.0
# 25    105583.0
# 26    116970.0
# 27    112636.0
# 28    122392.0
# 29    121873.0
# Name: Salary, dtype: float64

# %%
#input , output separated sofar

# %%
#now split train set and test set

# %%
#unlike pandas which is loading entire library, here only train_test_split , we downloading
from sklearn.model_selection import train_test_split
#train 80%, test 20%
x_train,x_test,y_train,y_test=train_test_split(independent, dependent, test_size=0.20, random_state=0)

# %%
#model_creation now
from sklearn.linear_model import LinearRegression
regressor=LinearRegression()
regressor.fit(x_train,y_train)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-21-2acaba76bf04> in <module>
#       2 from sklearn.linear_model import LinearRegression
#       3 regressor=LinearRegression()
# ----> 4 regressor.fit(x_train,y_train)
#
# ~\anaconda3\lib\site-packages\sklearn\linear_model\_base.py in fit(self, X, y, sample_weight)
#     503
#     504         n_jobs_ = self.n_jobs
# --> 505         X, y = self._validate_data(X, y, accept_sparse=['csr', 'csc', 'coo'],
#     506                                    y_numeric=True, multi_output=True)
#     507
#
# ~\anaconda3\lib\site-packages\sklearn\base.py in _validate_data(self, X, y, reset, validate_separately, **check_params)
#     430                 y = check_array(y, **check_y_params)
#     431             else:
# --> 432                 X, y = check_X_y(X, y, **check_params)
#     433             out = X, y
#     434
#
# ...

# %%
LinearRegression()
# Out:
# LinearRegression()

# %%
weight=regressor.coef_
weight
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-14-8c88d796e002> in <module>
# ----> 1 weight=regressor.coef_
#       2 weight
#
# AttributeError: 'LinearRegression' object has no attribute 'coef_'

# %%
bias=regressor.intercept_
bias
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-22-027e1c2eda60> in <module>
# ----> 1 bias=regressor.intercept_
#       2 bias
#
# AttributeError: 'LinearRegression' object has no attribute 'intercept_'

# %%
y_pred=regressor.predict(x_test)
# Out:
# ---------------------------------------------------------------------------
# NotFittedError                            Traceback (most recent call last)
# <ipython-input-23-350ddd5e0bb0> in <module>
# ----> 1 y_pred=regressor.predict(x_test)
#
# ~\anaconda3\lib\site-packages\sklearn\linear_model\_base.py in predict(self, X)
#     234             Returns predicted values.
#     235         """
# --> 236         return self._decision_function(X)
#     237
#     238     _preprocess_data = staticmethod(_preprocess_data)
#
# ~\anaconda3\lib\site-packages\sklearn\linear_model\_base.py in _decision_function(self, X)
#     214
#     215     def _decision_function(self, X):
# --> 216         check_is_fitted(self)
#     217
#     218         X = check_array(X, accept_sparse=['csr', 'csc', 'coo'])
#
# ~\anaconda3\lib\site-packages\sklearn\utils\validation.py in inner_f(*args, **kwargs)
#      70                           FutureWarning)
# ...

# %%
from sklearn.metrics import r2_score
r_score=re_score(y_test,y_pred)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-26-83b7f75dd0bf> in <module>
#       1 from sklearn.metrics import r2_score
# ----> 2 r_score=re_score(y_test,y_pred)
#
# NameError: name 're_score' is not defined

# %%
r_score
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-27-cb5f4c9382db> in <module>
# ----> 1 r_score
#
# NameError: name 'r_score' is not defined
